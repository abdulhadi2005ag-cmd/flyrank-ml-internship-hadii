# %% [markdown]
# <a href="https://colab.research.google.com/github/abdulhadi2005ag-cmd/flyrank-ml-internship-hadii/blob/main/work/notebooks/w01_research_question.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/abdulhadi2005ag-cmd/flyrank-ml-internship-hadii/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %%
# !git clone https://github.com/abdulhadi2005ag-cmd/flyrank-ml-internship-hadii
# %cd flyrank-ml-internship-hadii
# Out:
# Cloning into 'flyrank-ml-internship-hadii'...
# remote: Enumerating objects: 125, done.
# remote: Counting objects: 100% (125/125), done.
# remote: Compressing objects: 100% (80/80), done.
# remote: Total 125 (delta 40), reused 88 (delta 29), pack-reused 0 (from 0)
# Receiving objects: 100% (125/125), 1.85 MiB | 13.34 MiB/s, done.
# Resolving deltas: 100% (40/40), done.
# /content/flyrank-ml-internship-hadii/flyrank-ml-internship-hadii

# %%
# !ls data/raw/
# Out:
# content_refresh_anonymized.csv

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %%
print("""
Lane: Refresh / Content Opportunity Scoring (Lane 2)

I'm picking this lane because I already ran the exact comparison it's built on: a hand rule
score vs a random forest, on the starter dataset. The random forest beat the hand rule by a
wide margin, which means there's real signal in this data a fixed rule alone can't capture.
That's worth the next 7 weeks.
""")
# Out:
# Lane: Refresh / Content Opportunity Scoring (Lane 2)
#
# I'm picking this lane because I already ran the exact comparison it's built on: a hand rule
# score vs a random forest, on the starter dataset. The random forest beat the hand rule by a
# wide margin, which means there's real signal in this data a fixed rule alone can't capture.
# That's worth the next 7 weeks.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %%
print("""
One paragraph frame: For a content reviewer deciding which pages to review first, we will
build a ranked priority list from the starter content dataset, scoring pages by refresh
opportunity, measured by precision@50. A wrong call costs either wasted reviewer time (false
positive) or a missed declining page (false negative, more expensive). A plain rule isn't
enough because the hand rule only got 12 of its top 50 picks right, while a random forest got
37 of 50, so the pattern is real but too tangled for one simple rule. I'll claim only decision
support results, not proof that fixing a page causes recovery.

Task type: Ranking and scoring
Target: trend_direction == "down", a rule defined proxy label in the starter data, not a
future observed outcome. Known limitation, I'll address it by Week 4 with a real future window
target, prior 90 days predicting decline over the next 30 days.
Metric: precision@50
Who acts: a content reviewer with limited time
Action: opens the top ranked pages first instead of reviewing randomly
Cost of wrong call: false positive means wasted review time, cheap. False negative means a
real declining page goes unnoticed, expensive.
""")
# Out:
# One paragraph frame: For a content reviewer deciding which pages to review first, we will
# build a ranked priority list from the starter content dataset, scoring pages by refresh
# opportunity, measured by precision@50. A wrong call costs either wasted reviewer time (false
# positive) or a missed declining page (false negative, more expensive). A plain rule isn't
# enough because the hand rule only got 12 of its top 50 picks right, while a random forest got
# 37 of 50, so the pattern is real but too tangled for one simple rule. I'll claim only decision
# support results, not proof that fixing a page causes recovery.
#
# Task type: Ranking and scoring
# Target: trend_direction == "down", a rule defined proxy label in the starter data, not a
# future observed outcome. Known limitation, I'll address it by Week 4 with a real future window
# target, prior 90 days predicting decline over the next 30 days.
# Metric: precision@50
# Who acts: a content reviewer with limited time
# ...

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
import pandas as pd

df = pd.read_csv("data/raw/content_refresh_anonymized.csv")

print("Total pages in starter dataset:", len(df))
print("Clients represented:", df["client_id"].nunique())
print("Pages currently flagged declining:", (df["trend_direction"] == "down").sum())

print("""
Out of 30,000 pages across 32 clients in the starter dataset, a real chunk are currently
flagged as declining, see counts above. When I compared a simple hand rule score against a
random forest on this same data, the hand rule caught 12 of its top 50 picks correctly,
precision@50 equals 0.240, and the random forest caught 37 of 50, precision@50 equals 0.740.
That's triple the hit rate, and it's the real evidence this lane is worth pursuing.
""")
# Out:
# Total pages in starter dataset: 30000
# Clients represented: 32
# Pages currently flagged declining: 16262
#
# Out of 30,000 pages across 32 clients in the starter dataset, a real chunk are currently
# flagged as declining, see counts above. When I compared a simple hand rule score against a
# random forest on this same data, the hand rule caught 12 of its top 50 picks correctly,
# precision@50 equals 0.240, and the random forest caught 37 of 50, precision@50 equals 0.740.
# That's triple the hit rate, and it's the real evidence this lane is worth pursuing.

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %%
print("""
What I can claim: this ranks pages by evidence, so a reviewer's limited time goes to the most
promising candidates first. This is decision support, not automation.

What I can't claim: that fixing a flagged page will cause its traffic to recover, that needs a
real experiment. I also can't claim I've found a Google ranking factor, only patterns in
FlyRank's own observed data. And right now I'm using a rule derived label, trend_direction,
not a true future outcome, so today's numbers describe whether I can predict the current rule
more than whether I can predict the future. I'll fix that by Week 4 with a real future window
target.
""")
# Out:
# What I can claim: this ranks pages by evidence, so a reviewer's limited time goes to the most
# promising candidates first. This is decision support, not automation.
#
# What I can't claim: that fixing a flagged page will cause its traffic to recover, that needs a
# real experiment. I also can't claim I've found a Google ranking factor, only patterns in
# FlyRank's own observed data. And right now I'm using a rule derived label, trend_direction,
# not a true future outcome, so today's numbers describe whether I can predict the current rule
# more than whether I can predict the future. I'll fix that by Week 4 with a real future window
# target.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
